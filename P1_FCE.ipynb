# %% [markdown]
# <a href="https://colab.research.google.com/github/jpfabri38558/P1_FCE/blob/main/P1_FCE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Primeira Avaliação - Fundamentos Computacionais para Engenharia
#
# ---
#
# 22 de Abril de 2026
#
# Nome: João Pedro Sobreira Fabri
#
# Matrícula: 2023100972

# %% [markdown]
# ## Questão 1)

# %% [markdown]
# >*“Programar não é apenas escrever código, mas estruturar logicamente uma solução.”*
#
# Antes de escrever o código, na programação, é necessário desenvolver o problema e estruturar uma solução lógica.
#
# Para isso, o programador deve estruturar um **algoritmo**, isto é, uma sequência finita de passos para resolver um problema.
#
# A fim de garantir que a máquina interprete corretamente a solução, o algoritmo deve respeitar a **lógica computacional**. Essa lógica aplica princípios matemáticos e estruturais para resolver o problema de forma clara, precisa e sistemática, utilizando operadores lógicos, estruturas condicionais (“se... então... senão...”) e laços de repetição (“enquanto... faça...” e “para... faça...”).
#
# Por fim, o programador pode escrever o código com base no desenvolvido, sendo como uma tradução desse algoritmo para uma linguagem de programação específica.
#
# Exemplo:
# >Algoritmo para ler a altura de uma pessoa e verificar se ela tem a altura mínima necessária para um brinquedo (1,40 m)
#
# Pseudocódigo:
# ```
# Início
#
#     AlturaMinima = 1,4
#
#     Leia(Altura)
#
#     Se Altura < AlturaMinima:
#
#         Escreva(Não pode andar no brinquedo :/)
#
#     Senão:
#
#         Escreva(Pode andar no brinquedo :D)
#
# Fim
# ```
#
# Código em python:
# ```
# AlturaMinima = 1.4
#
# Altura = float(input("Digite a altura (metros): "))
#
# if Altura < AlturaMinima:
#   print("Não Pode andar no brinquedo :/")
#
# else:
#   print("Pode andar no brinquedo :D")
# ```

# %% [markdown]
# ##Questão 2)

# %% [markdown]
# ###(a)

# %% [markdown]
# - **Vantagens**: *Compartilhamento facilitado* <sup>1</sup> (para leitores, comentadores e editores) e *visualização integrada de código e texto* <sup>2</sup> (podendo adicionar explicações amplas e formatadas, imagens, tabelas e exemplos entre os códigos).
#
# - **Limitações**: *Erros na ordem de execução* <sup>1</sup> (ao rodar o código por partes, a ordem de execução pode se tornar um problema) e *baixa performance para códigos mais pesados* <sup>2</sup> (em aplicações maiores, a otimização pode ser dificultada, tornando o código lento).

# %% [markdown]
# ###(b)

# %% [markdown]
# A execução das células fora de ordem pode ocasionar diversos problemas, como o uso de variáveis ou funções que ainda não foram definidas ou que sofreram alterações e não foram atualizadas.
#
# Um erro difícil de identificar, por exemplo, pode ocorrer quando uma variável não sofre uma alteração necessária para a continuidade do código, devido a uma célula não ter sido executada ou ter sido executada em um momento errado.

# %% [markdown]
# ##Questão 3)

# %% [markdown]
# ###(a)

# %% [markdown]
# ```
# Início
#
#     contador = 0
#
#     Enquanto verdadeiro faça:
#
#         Leia(nível)
#
#         Se nível > 100 ou nível < 0 então:
#
#             Escreva(Erro de leitura)
#             Pare
#
#         Senão então:
#
#             Se nível > 80 então:
#                 Escreva(Risco de transbordamento)
#                 contador = 0
#
#             Senão Se nível >= 20 então:
#                 Escreva(Operação normal)
#                 contador = 0
#
#             Senão então:
#                 Escreva(Nível baixo)
#                 contador = contador + 1
#
#                 Se contador = 3 então:
#                     Escreva(Alerta de parada)
#                     Pare
#
# Fim
# ```

# %% [markdown]
# ###(b)

# %%
from graphviz import Digraph

g = Digraph()

# ========
# Nós
# ========

g.node('A', 'Início')
g.node('B', 'Ler nível', shape='box')
g.node('C', 'nível > 100% ou nível < 0% ?', shape='diamond')
g.node('D', 'Erro de leitura', shape='box')
g.node('E', 'nível > 80% ?', shape='diamond')
g.node('F', 'Risco de transbordamento', shape='box')
g.node('G', 'nível >= 20% ?', shape='diamond')
g.node('H', 'Operação normal', shape='box')
g.node('I', 'Nível baixo', shape='box')
g.node('J', 'contador = contador + 1', shape='box')
g.node('K', 'contador = 3 ?', shape='diamond')
g.node('L', 'Alerta de parada', shape='box')
g.node('M', 'Fim')

# ========
# Conexões
# ========

# Início
g.edge('A', 'B')
g.edge('B', 'C')

# Verificação de a leitura é válida
g.edge('C', 'D', label='Sim')
g.edge('D', 'M', label='Pare') # Leitura inválida

g.edge('C', 'E', label='Não') # Leitura válida

# Verificação de risco de transbordamento
g.edge('E', 'F', label='Sim') # 100 >= Nível > 80
g.edge('F', 'B')

g.edge('E', 'G', label='Não') # 80 >= Nível

# Verificação de operação normal
g.edge('G', 'H', label='Sim') # 80 >= Nível >= 20
g.edge('H', 'B')

# Nível baixo
g.edge('G', 'I', label='Não') # 20 > Nível >= 0
g.edge('I', 'J')
g.edge('J', 'K')

# Verificação do contador de nível baixo
g.edge('K', 'L', label='Sim') # Contador = 3
g.edge('L', 'M', label='Pare')

g.edge('K', 'B', label='Não') # Contador < 3

g

# %% [markdown]
# ###(c)

# %% [markdown]
# **Entrada:**
# 1. Leitura do valor do nível
#
# **Processamento:**
# 1. Inicializa um contador (`contador = 0`) para níveis baixos;
# 2. Entra em um loop infinito (`enquanto verdadeiro`);
# 3. Realiza a Entrada (1);
# 4. Verifica se a leitura é válida (nível entre 0% e 100%):
# 4.1. Se não: Saída (1) e encerra o algoritmo;
# 4.2. Se sim: continua;
# 5. Verifica se o nível é maior que 80%:
# 5.1. Se sim: Saída (2), (`contador = 0`) e retorna para nova leitura;
# 5.2. Se não: continua;
# 6. Verifica se o nível é maior ou igual a 20%:
# 6.1. Se sim: Saída (3), (`contador = 0`) e retorna para nova leitura;
# 6.2. Se não: Saída (4), (`contador = contador + 1`) e continua;
# 7. Verifica se o contador é igual a 3:
# 7.1. Se sim: Saída (5) e encerra o algoritmo;
# 7.2. Se não: retorna para nova leitura;
#
# **Saída:**
# 1. Erro de leitura
# 2. Risco de transbordamento
# 3. Operação normal
# 4. Nível baixo
# 5. Alerta de parada

# %% [markdown]
# ## Questão 4)

# %%
import numpy as np


def CondSis(C, r = 0): # Condição do Sistema
  """
  Essa função analisa a condição da concentração de reagente no sistema,
  considerando valores entre 0 e 10 mol/L.

  C: concentração do reagente em mol/L.
  r: número da leitura.
  cond: condição do sistema.
  """

  if C > 10 or C < 0:
    # Leitura inválida
    raise ValueError("A concentração deve ser entre 0 e 10 mol/L")

  elif C > 7:
    cond = "Alta"

  elif C >= 3:
    cond = "Adequada"

  else:
    cond = "Baixa"

  print(f"Leitura {r}:")
  print(f"  Concentração de reagente = {C:.4f} mol/L") # 0.0000
  print(f"  Condição do sistema: {cond}\n") # Alta, Adequada ou Baixa

  return cond


def Sim(n): # Simulação
  """
  Essa função simula leituras de concentração de reagente no sistema,
  considerando valores entre 0 e 10 mol/L.

  n: número de simulações desejadas.
  C: concentração do reagente em mol/L.
  r: número da leitura.
  cond: condição do sistema.
  cont: dicionário com as ocorrências de cada condição de concentração.
  """

  cont = {'Alta': 0, 'Adequada': 0, 'Baixa': 0} # Dicionário de contadores

  print("="*60)
  print(f"Simulação de {n} entradas")
  print("="*60 + "\n")

  for i in range(n):
    C = np.random.uniform(0, 10) # Número aleatório contínuo entre 0 e 10
    r = i + 1 # i = 0 -> primeira leitura

    cond = CondSis(C, r) # Alta, Adequada ou Baixa
    cont[cond] += 1 # Adiciona 1 ao contador correspondente a condição

  return cont


def Res(cont): # Resumo
  """
  Essa função exibe um resumo das ocorrências de cada condição de
  concentração, indicando a frequência de cada e a condição predominante.

  cont: dicionário com as ocorrências de cada condição de concentração.
  """

  print("="*60)
  print("Resumo")
  print("="*60 + "\n")

  print(f"  Concentração Alta: {cont['Alta']} ocorrências")
  print(f"  Concentração Adequada: {cont['Adequada']} ocorrências")
  print(f"  Concentração Baixa: {cont['Baixa']} ocorrências")
  print(f"\n  Concentração Predominante: {max(cont, key=cont.get)}")
  # Nota ética: tive que pesquisar como utilizar a função max em um dicinário
  # max(dicionário, key=dicionário.get) -> pega a chave do maior valor


Res(Sim(10))
# Out:
# ...
# Simulação de 10 entradas
# ...
#
# Leitura 1:
#   Concentração de reagente = 0.6748 mol/L
#   Condição do sistema: Baixa
#
# Leitura 2:
#   Concentração de reagente = 1.4907 mol/L
#   Condição do sistema: Baixa
#
# Leitura 3:
#   Concentração de reagente = 0.1711 mol/L
#   Condição do sistema: Baixa
#
# Leitura 4:
#   Concentração de reagente = 6.2301 mol/L
#   Condição do sistema: Adequada
#
# Leitura 5:
#   Concentração de reagente = 7.9112 mol/L
#   Condição do sistema: Alta
#
# Leitura 6:
#   Concentração de reagente = 9.2345 mol/L
#   Condição do sistema: Alta
#
# Leitura 7:
#   Concentração de reagente = 0.6603 mol/L
#   Condição do sistema: Baixa
#
# Leitura 8:
#   Concentração de reagente = 0.3128 mol/L
#   Condição do sistema: Baixa
#
# Leitura 9:
#   Concentração de reagente = 3.2942 mol/L
#   Condição do sistema: Adequada
#
# Leitura 10:
#   Concentração de reagente = 6.2797 mol/L
#   Condição do sistema: Adequada
#
# ...
# Resumo
# ...
#
#   Concentração Alta: 2 ocorrências
# ...
